# %%
from datetime import datetime

# %%
dt = datetime(year = 2020, month = 12, day = 15)

# %%
import numpy as np

# %%
np.array(['2020-12-11', '2020-12-15'])
# Out:
# array(['2020-12-11', '2020-12-15'], dtype='<U10')

# %%
np.array(['2020-12-11', '2020-12-15'], dtype = 'datetime64')
# Out:
# array(['2020-12-11', '2020-12-15'], dtype='datetime64[D]')

# %% [markdown]
# # [D] stands for date level precision
# # [Y] stands for year level precision
# # [h] stands for hour level precision
# # [ns] stands for nano sec level precision

# %%
np.array(['2020-12-11', '2020-12-15'], dtype = 'datetime64[Y]')
# Out:
# array(['2020', '2020'], dtype='datetime64[Y]')

# %%
np.arange('2013-03-01', '2020-12-31', 3, dtype = 'datetime64[M]')
# Out:
# array(['2013-03', '2013-06', '2013-09', '2013-12', '2014-03', '2014-06',
#        '2014-09', '2014-12', '2015-03', '2015-06', '2015-09', '2015-12',
#        '2016-03', '2016-06', '2016-09', '2016-12', '2017-03', '2017-06',
#        '2017-09', '2017-12', '2018-03', '2018-06', '2018-09', '2018-12',
#        '2019-03', '2019-06', '2019-09', '2019-12', '2020-03', '2020-06',
#        '2020-09'], dtype='datetime64[M]')

# %%
import pandas as pd

# %%
pd.date_range(start='2013-03-31', end='2020-12-31', freq='Q')
# Out:
# DatetimeIndex(['2013-03-31', '2013-06-30', '2013-09-30', '2013-12-31',
#                '2014-03-31', '2014-06-30', '2014-09-30', '2014-12-31',
#                '2015-03-31', '2015-06-30', '2015-09-30', '2015-12-31',
#                '2016-03-31', '2016-06-30', '2016-09-30', '2016-12-31',
#                '2017-03-31', '2017-06-30', '2017-09-30', '2017-12-31',
#                '2018-03-31', '2018-06-30', '2018-09-30', '2018-12-31',
#                '2019-03-31', '2019-06-30', '2019-09-30', '2019-12-31',
#                '2020-03-31', '2020-06-30', '2020-09-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
pd.date_range(start='2013-03-31', periods=3, freq='Q')
# Out:
# DatetimeIndex(['2013-03-31', '2013-06-30', '2013-09-30'], dtype='datetime64[ns]', freq='Q-DEC')

# %%
pd.date_range(start='Mar 31, 2013', end='Dec 31, 2020', freq='Q')
# Out:
# DatetimeIndex(['2013-03-31', '2013-06-30', '2013-09-30', '2013-12-31',
#                '2014-03-31', '2014-06-30', '2014-09-30', '2014-12-31',
#                '2015-03-31', '2015-06-30', '2015-09-30', '2015-12-31',
#                '2016-03-31', '2016-06-30', '2016-09-30', '2016-12-31',
#                '2017-03-31', '2017-06-30', '2017-09-30', '2017-12-31',
#                '2018-03-31', '2018-06-30', '2018-09-30', '2018-12-31',
#                '2019-03-31', '2019-06-30', '2019-09-30', '2019-12-31',
#                '2020-03-31', '2020-06-30', '2020-09-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
pd.to_datetime(['1/1/2013', 'Jan 03, 2018'])
# Out:
# DatetimeIndex(['2013-01-01', '2018-01-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['1/1/2013', '1/3/2018'])
# Out:
# DatetimeIndex(['2013-01-01', '2018-01-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['1/1/2013', '3/1/2018'])
# Out:
# DatetimeIndex(['2013-01-01', '2018-03-01'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['1/1/2013', '3/1/2018'], format="%m/%d/%Y")
# Out:
# DatetimeIndex(['2013-01-01', '2018-03-01'], dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(data = np.random.randn(3,2), index= pd.date_range(start='2020-01-01', periods=3, freq='D'), columns=['A','B'])
df
# Out:
#                    A         B
# 2020-01-01 -1.244216 -0.227640
# 2020-01-02 -0.455974  0.177916
# 2020-01-03 -0.335919  0.705676

# %%
pd.DataFrame(data = np.random.randn(3,2), index= pd.date_range(start='2020-01-01', end='2020-01-03', freq='D'), columns=['A','B'])
# Out:
#                    A         B
# 2020-01-01 -0.957851  0.802790
# 2020-01-02  0.227227  0.429888
# 2020-01-03  0.291674 -0.461597

# %%
pd.DataFrame(data = np.random.randn(3,2), index=np.arange('2020-01-01','2020-01-04', dtype = 'datetime64'), columns=['A','B'])
# Out:
#                    A         B
# 2020-01-01 -0.362197  1.079934
# 2020-01-02  1.581328  0.052329
# 2020-01-03 -0.052452 -1.083003

# %%
df.index.min()
# Out:
# Timestamp('2020-01-01 00:00:00', freq='D')

# %%
df.index.argmax()
# Out:
# 2

# %%
df = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\starbucks.csv", parse_dates=['Date'], index_col=['Date'])

# %%
df
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %% [markdown]
# # Resample

# %% [markdown]
# # Let's say we want to agg by Quarterly level

# %% [markdown]
# ### rule can be found in https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases

# %%
df.resample(rule='A').mean()
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
df.resample('QS').sum()
# Out:
#                 Close     Volume
# Date
# 2015-01-01  2564.0560  613557044
# 2015-04-01  3000.2160  464668975
# 2015-07-01  3375.5225  589202217
# 2015-10-01  3679.8866  512167660
# 2016-01-01  3365.4738  667237588
# 2016-04-01  3459.2278  549293792
# 2016-07-01  3414.4370  575781713
# 2016-10-01  3341.5778  551446422
# 2017-01-01  3375.7148  610468287
# 2017-04-01  3680.9039  512282894
# 2017-07-01  3387.6449  641284952
# 2017-10-01  3475.5213  569279404
# 2018-01-01  3457.3607  667081678
# 2018-04-01  3579.8876  667650966
# 2018-07-01  3304.0988  620536592
# 2018-10-01  3933.0241  863166433

# %%
df.resample('Q').sum()
# Out:
#                 Close     Volume
# Date
# 2015-03-31  2564.0560  613557044
# 2015-06-30  3000.2160  464668975
# 2015-09-30  3375.5225  589202217
# 2015-12-31  3679.8866  512167660
# 2016-03-31  3365.4738  667237588
# 2016-06-30  3459.2278  549293792
# 2016-09-30  3414.4370  575781713
# 2016-12-31  3341.5778  551446422
# 2017-03-31  3375.7148  610468287
# 2017-06-30  3680.9039  512282894
# 2017-09-30  3387.6449  641284952
# 2017-12-31  3475.5213  569279404
# 2018-03-31  3457.3607  667081678
# 2018-06-30  3579.8876  667650966
# 2018-09-30  3304.0988  620536592
# 2018-12-31  3933.0241  863166433

# %% [markdown]
# # Custom resampling methods

# %%
def last_entry(entry):
    if len(entry)!= 0:
        return entry[-1]

# %%
df.resample('A').apply(last_entry)
# Out:
#               Close   Volume
# Date
# 2015-12-31  56.7513  4960875
# 2016-12-31  53.2731  8344508
# 2017-12-31  56.1288  5365646
# 2018-12-31  64.4000  7690183

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['Volume'].resample("Q").mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Time Shifting

# %% [markdown]
# # Shift down by 1 row

# %%
df.shift(1)
# Out:
#               Close      Volume
# Date
# 2015-01-02      NaN         NaN
# 2015-01-05  38.0061   6906098.0
# 2015-01-06  37.2781  11623796.0
# 2015-01-07  36.9748   7664340.0
# 2015-01-08  37.8848   9732554.0
# ...             ...         ...
# 2018-12-24  61.3900  23524888.0
# 2018-12-26  60.5600   6323252.0
# 2018-12-27  63.0800  16646238.0
# 2018-12-28  63.2000  11308081.0
# 2018-12-31  63.3900   7712127.0
#
# [1006 rows x 2 columns]

# %% [markdown]
# # Shift up by one row

# %%
df.shift(-1)
# Out:
#               Close      Volume
# Date
# 2015-01-02  37.2781  11623796.0
# 2015-01-05  36.9748   7664340.0
# 2015-01-06  37.8848   9732554.0
# 2015-01-07  38.4961  13170548.0
# 2015-01-08  37.2361  27556706.0
# ...             ...         ...
# 2018-12-24  63.0800  16646238.0
# 2018-12-26  63.2000  11308081.0
# 2018-12-27  63.3900   7712127.0
# 2018-12-28  64.4000   7690183.0
# 2018-12-31      NaN         NaN
#
# [1006 rows x 2 columns]

# %% [markdown]
# # Shift by period, freq

# %% [markdown]
# ## Everything is shifted by end of month

# %%
df.shift(periods=1, freq='M')
# Out:
#               Close    Volume
# Date
# 2015-01-31  38.0061   6906098
# 2015-01-31  37.2781  11623796
# 2015-01-31  36.9748   7664340
# 2015-01-31  37.8848   9732554
# 2015-01-31  38.4961  13170548
# ...             ...       ...
# 2018-12-31  60.5600   6323252
# 2018-12-31  63.0800  16646238
# 2018-12-31  63.2000  11308081
# 2018-12-31  63.3900   7712127
# 2019-01-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %% [markdown]
# # Rolling and Expanding

# %%
df['Close'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## First 6 rows will be NaN as the window criteria is still not fulfilled which is 7 in this case

# %%
df.rolling(window=7).mean()['Close']
# Out:
# Date
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08          NaN
#                 ...
# 2018-12-24    63.270000
# 2018-12-26    62.947143
# 2018-12-27    62.765714
# 2018-12-28    62.547143
# 2018-12-31    62.595714
# Name: Close, Length: 1006, dtype: float64

# %%
df['Close'].plot(figsize = (12,5))
df.rolling(window=30).mean()['Close'].plot(figsize = (12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].plot(figsize = (12,5))
df.rolling(window=364).mean()['Close'].plot(figsize = (12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(38.0061+37.2781+36.9748)/3 # exapanding is following this pattern
# Out:
# 37.419666666666664

# %%
df['Close']
# Out:
# Date
# 2015-01-02    38.0061
# 2015-01-05    37.2781
# 2015-01-06    36.9748
# 2015-01-07    37.8848
# 2015-01-08    38.4961
#                ...
# 2018-12-24    60.5600
# 2018-12-26    63.0800
# 2018-12-27    63.2000
# 2018-12-28    63.3900
# 2018-12-31    64.4000
# Name: Close, Length: 1006, dtype: float64

# %%
df['Close'].expanding().mean()
# Out:
# Date
# 2015-01-02    38.006100
# 2015-01-05    37.642100
# 2015-01-06    37.419667
# 2015-01-07    37.535950
# 2015-01-08    37.727980
#                 ...
# 2018-12-24    54.032419
# 2018-12-26    54.041439
# 2018-12-27    54.050561
# 2018-12-28    54.059854
# 2018-12-31    54.070133
# Name: Close, Length: 1006, dtype: float64

# %% [markdown]
# # last value is the avg val of the entire series

# %%
df['Close'].expanding().mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Viz Time series

# %%
df['Close'].plot();

# %%
df.plot(); #1e7 means scales are n x 10^7

# %%
df['Volume'].plot(figsize = (12,5));
plt.xlabel('Dates');
plt.ylabel('Vol')
plt.autoscale()

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df['Close'].plot(figsize = (20,10), xlim = ['2017-01-01', '2017-12-31'], ylim = [40,60]);
plt.autoscale()

# %%
df['Close']['2017-01-01':'2017-12-31'].plot(figsize = (20,10), ylim = [60,70], ls = '--');
plt.autoscale()

# %%
df1 = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\monthly_milk_production.csv", parse_dates=['Date'], index_col=['Date'])

# %%
df1
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727
# ...                ...
# 1975-08-01         858
# 1975-09-01         817
# 1975-10-01         827
# 1975-11-01         797
# 1975-12-01         843
#
# [168 rows x 1 columns]

# %%
df1.index
# Out:
# DatetimeIndex(['1962-01-01', '1962-02-01', '1962-03-01', '1962-04-01',
#                '1962-05-01', '1962-06-01', '1962-07-01', '1962-08-01',
#                '1962-09-01', '1962-10-01',
#                ...
#                '1975-03-01', '1975-04-01', '1975-05-01', '1975-06-01',
#                '1975-07-01', '1975-08-01', '1975-09-01', '1975-10-01',
#                '1975-11-01', '1975-12-01'],
#               dtype='datetime64[ns]', name='Date', length=168, freq=None)

# %%
type(df1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df1.Production.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df1['Month'] = df1.index.month

# %%
df1
# Out:
#             Production  Month
# Date
# 1962-01-01         589      1
# 1962-02-01         561      2
# 1962-03-01         640      3
# 1962-04-01         656      4
# 1962-05-01         727      5
# ...                ...    ...
# 1975-08-01         858      8
# 1975-09-01         817      9
# 1975-10-01         827     10
# 1975-11-01         797     11
# 1975-12-01         843     12
#
# [168 rows x 2 columns]

# %%
import seaborn as sns

# %%
sns.boxplot(x = df1.Month, y = df1.Production)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Production'>

# %%
df1 = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\UMTMVS.csv", parse_dates=['DATE'], index_col=['DATE'])

# %%
df1
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0
# ...              ...
# 2018-09-01  516992.0
# 2018-10-01  527031.0
# 2018-11-01  495901.0
# 2018-12-01  490076.0
# 2019-01-01  466791.0
#
# [325 rows x 1 columns]

# %%
df1.plot(figsize = (20,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df1.loc['2009-01-01':'2019-01-01','UMTMVS'].resample('Y').sum()
# Out:
# DATE
# 2009-12-31    4423779.0
# 2010-12-31    4911277.0
# 2011-12-31    5491894.0
# 2012-12-31    5696728.0
# 2013-12-31    5809745.0
# 2014-12-31    5887559.0
# 2015-12-31    5519020.0
# 2016-12-31    5354694.0
# 2017-12-31    5604916.0
# 2018-12-31    5999570.0
# 2019-12-31     466791.0
# Freq: A-DEC, Name: UMTMVS, dtype: float64

# %%
(df1.loc['2008-01-01':'2009-12-31','UMTMVS'].resample('Y').sum()[-1] - df1.loc['2008-01-01':'2009-12-31','UMTMVS'].resample('Y').sum()[0])/df1.loc['2008-01-01':'2019-12-31','UMTMVS'].resample('Y').sum()[0]
# Out:
# -0.19111650149917883

# %%
df1.loc['2005-01-01':,:].index[df1.loc['2005-01-01':,'UMTMVS'].argmin()]
# Out:
# Timestamp('2009-01-01 00:00:00')

# %%
df1["Month"] = df1.index.month

# %%
df1.UMTMVS.resample('Y').mean().plot(figsize = (20,4), kind = 'bar')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df1.index[df1.UMTMVS.resample('Y').mean().argmax()]
# Out:
# Timestamp('1994-03-01 00:00:00')

# %%
df1.UMTMVS.expanding().mean()
# Out:
# DATE
# 1992-01-01    209438.000000
# 1992-02-01    221058.500000
# 1992-03-01    230596.666667
# 1992-04-01    232864.000000
# 1992-05-01    234937.400000
#                   ...
# 2018-09-01    380549.267913
# 2018-10-01    381004.180124
# 2018-11-01    381359.897833
# 2018-12-01    381695.441358
# 2019-01-01    381957.273846
# Name: UMTMVS, Length: 325, dtype: float64

# %% [markdown]
# # Statsmodel Time Series API

# %% [markdown]
# # Hordick Prescot Filter to seperate out the trend and cyclic component of a given time series data

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter

# %%
df = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\macrodata.csv", parse_dates=True, index_col=0)

# %%
df
# Out:
#             year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 1959-03-31  1959        1   2710.349    1707.4   286.898   470.045   1886.9
# 1959-06-30  1959        2   2778.801    1733.7   310.859   481.301   1919.7
# 1959-09-30  1959        3   2775.488    1751.8   289.226   491.260   1916.4
# 1959-12-31  1959        4   2785.204    1753.7   299.356   484.052   1931.3
# 1960-03-31  1960        1   2847.699    1770.5   331.722   462.199   1955.5
# ...          ...      ...        ...       ...       ...       ...      ...
# 2008-09-30  2008        3  13324.600    9267.7  1990.693   991.551   9838.3
# 2008-12-31  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4
# 2009-03-31  2009        1  12925.410    9209.2  1558.494   996.287   9926.4
# 2009-06-30  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5
# 2009-09-30  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6
#
# ...

# %%
gdp_cyc, gdp_trend = hpfilter(df['realgdp'], lamb=1600) # as quarterly data

# %%
df['realgdp'].plot()
gdp_trend.plot();
gdp_cyc.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ETS Decomposition(Error - Trend - Seasonality)

# %%
df= pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\airline_passengers.csv", parse_dates=['Month'], index_col=['Month'])

# %%
df
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
df.isna().sum()
# Out:
# Thousands of Passengers    0
# dtype: int64

# %%
df.plot();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
res = seasonal_decompose(df['Thousands of Passengers'], model = 'mul')

# %%
res.observed.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
res.seasonal.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
res.trend.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
res.resid.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12,5
res.plot();

# %% [markdown]
# # Exponentialy Weighted Moving Average

# %% [markdown]
# ### Creating an 6 and 12 Month SMA for comparison

# %%
df['SMA_6M'] = df['Thousands of Passengers'].rolling(window=6).mean()

# %%
df['SMA_12M'] = df['Thousands of Passengers'].rolling(window=12).mean()

# %%
df['Thousands of Passengers'].plot()
df['SMA_6M'].plot()
df['SMA_12M'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Alpha can be determined by span = N day EWMA = 2/1+s , com = Center of mass = 1/1+c and half life = 1 - e ^(log 0.5/h)

# %%
df['EWMA_12'] = df['Thousands of Passengers'].ewm(span = 12).mean()
df['EWMA_6'] = df['Thousands of Passengers'].ewm(span = 6).mean()

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Holt-Winter's Exponential Smoothing

# %%
df = df.iloc[:,0]
df
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: Thousands of Passengers, Length: 144, dtype: int64

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %% [markdown]
# # As the freq is set to none, we can set the freq to our desired based on the rule provided by stats model
# # Since data is collected at start of month hence we choose MS

# %%
df.index.freq = "MS"

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq='MS')

# %% [markdown]
# adjustbool, default True
# Divide by decaying adjustment factor in beginning periods to account for imbalance in relative weightings (viewing EWMA as a moving average).
#
# When adjust=True (default), the EW function is calculated using weights wi=(1−α)i. For example, the EW moving average of the series [x0,x1,...,xt] would be:
#
# yt=xt+(1−α)xt−1+(1−α)2xt−2+...+(1−α)tx01+(1−α)+(1−α)2+...+(1−α)t
# When adjust=False, the exponentially weighted function is calculated recursively:
#
# y0yt=x0=(1−α)yt−1+αxt,

# %%
s = 12

# %%
alpha = 2/(s + 1)

# %%
alpha
# Out:
# 0.15384615384615385

# %%
df.plot();
df.ewm(alpha = 2/(12+1), adjust=False).mean().plot();
df.ewm(alpha = 2/(12+1), adjust=True).mean().plot();

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, ExponentialSmoothing

# %%
model = SimpleExpSmoothing(df)

# %% [markdown]
# # Smoothing level is alpha

# %%
model = model.fit(smoothing_level = 2/(12+1), optimized=False)

# %% [markdown]
# # Since optimized = False so we see repeat in the first value so shift by -1

# %%
model.fittedvalues.shift(-1)
# Out:
# Month
# 1949-01-01    112.000000
# 1949-02-01    112.923077
# 1949-03-01    115.857988
# 1949-04-01    117.879836
# 1949-05-01    118.359861
#                  ...
# 1960-08-01    494.898619
# 1960-09-01    496.914216
# 1960-10-01    491.388952
# 1960-11-01    475.790652
# 1960-12-01           NaN
# Freq: MS, Length: 144, dtype: float64

# %%
model = ExponentialSmoothing(df, trend='add').fit().fittedvalues.shift(-1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
df.plot()
model.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
model = ExponentialSmoothing(df, trend='mul').fit().fittedvalues.shift(-1)

df.plot()
model.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Triple Exponential Smoothing - Holt Winter's Method

# %% [markdown]
# ### Here we have to see if the Seasonality if also inc proportionally or exponentially with time and then choose mul or add

# %%
model = ExponentialSmoothing(df, trend='mul', seasonal='mul', seasonal_periods=12).fit().fittedvalues
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:725: RuntimeWarning: invalid value encountered in less_equal
#   loc = initial_p <= lb
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
df.plot()
model.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Testing Knowledge Gained

# %%
df = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\EnergyProduction.csv", parse_dates=['DATE'], index_col=['DATE'])

# %%
df
# Out:
#             EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321
# ...                 ...
# 1989-08-01      75.2704
# 1989-09-01      69.5107
# 1989-10-01      66.0620
# 1989-11-01      69.2555
# 1989-12-01      84.4040
#
# [240 rows x 1 columns]

# %%
df.index.freq = 'MS'

# %%
df.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '1989-03-01', '1989-04-01', '1989-05-01', '1989-06-01',
#                '1989-07-01', '1989-08-01', '1989-09-01', '1989-10-01',
#                '1989-11-01', '1989-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=240, freq='MS')

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing

# %%
model = SimpleExpSmoothing(df['EnergyIndex'])

# %%
model = model.fit(smoothing_level=2/(1+12), optimized=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
df['SES_12'] = model.fittedvalues

# %%
df[['EnergyIndex','SES_12']].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df['SMA_12'] = df['EnergyIndex'].rolling(window=12).mean()

# %%
df['TES_12'] = ExponentialSmoothing(df['EnergyIndex'], trend='mul', seasonal='mul', seasonal_periods=12).fit().fittedvalues
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:725: RuntimeWarning: invalid value encountered in less_equal
#   loc = initial_p <= lb
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
df[['EnergyIndex','SES_12','TES_12','SMA_12']][:24].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# # Advanced Forecasting -

# %%
df = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\airline_passengers.csv", parse_dates=['Month'], index_col=['Month'])

# %%
df
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
df.index.freq = 'MS'

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq='MS')

# %%
train = df.loc[:'1959-12-01']
test = df.loc['1960-01-01':]

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
fitted_model = ExponentialSmoothing(train['Thousands of Passengers'], trend = 'mul', seasonal='mul', seasonal_periods=12).fit()

# %%
test_pred = fitted_model.forecast(steps = 12)

# %%
test_pred
# Out:
# 1960-01-01    420.906515
# 1960-02-01    399.215504
# 1960-03-01    470.317935
# 1960-04-01    458.254529
# 1960-05-01    483.830647
# 1960-06-01    556.244640
# 1960-07-01    644.515062
# 1960-08-01    654.617167
# 1960-09-01    537.142802
# 1960-10-01    470.785539
# 1960-11-01    414.192143
# 1960-12-01    448.647449
# Freq: MS, dtype: float64

# %%
test['Forecasted_Thousands_of_Passengers'] = test_pred
# Out:
# <ipython-input-146-bbd4e8543fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Forecasted_Thousands_of_Passengers'] = test_pred

# %%
test
# Out:
#             Thousands of Passengers  Forecasted_Thousands_of_Passengers
# Month
# 1960-01-01                      417                          420.906515
# 1960-02-01                      391                          399.215504
# 1960-03-01                      419                          470.317935
# 1960-04-01                      461                          458.254529
# 1960-05-01                      472                          483.830647
# 1960-06-01                      535                          556.244640
# 1960-07-01                      622                          644.515062
# 1960-08-01                      606                          654.617167
# 1960-09-01                      508                          537.142802
# 1960-10-01                      461                          470.785539
# 1960-11-01                      390                          414.192143
# 1960-12-01                      432                          448.647449

# %%
train['Thousands of Passengers'].plot(legend = True, label = 'Train', figsize = (12,4))
test['Thousands of Passengers'].plot(legend = True, label = 'Test', figsize = (12,4))
test['Forecasted_Thousands_of_Passengers'].plot(legend = True, label = 'Forecasted', figsize = (12,4))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from sklearn.metrics import mean_squared_error

# %%
import numpy as np

# %%
np.sqrt(mean_squared_error(test['Thousands of Passengers'], test['Forecasted_Thousands_of_Passengers']))
# Out:
# 25.808810392797046

# %%
final_model = ExponentialSmoothing(df['Thousands of Passengers'], trend = 'mul', seasonal='mul', seasonal_periods=12).fit()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:725: RuntimeWarning: invalid value encountered in less_equal
#   loc = initial_p <= lb
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
df = pd.concat([df,pd.DataFrame(final_model.forecast(steps = 12), columns=['Thousands of Passengers'])])
df
# Out:
#             Thousands of Passengers
# 1949-01-01               112.000000
# 1949-02-01               118.000000
# 1949-03-01               132.000000
# 1949-04-01               129.000000
# 1949-05-01               121.000000
# ...                             ...
# 1961-08-01               678.042247
# 1961-09-01               567.118995
# 1961-10-01               507.827864
# 1961-11-01               434.725056
# 1961-12-01               485.987531
#
# [156 rows x 1 columns]

# %% [markdown]
# # Stationarity vs Non Stationarity TS Data

# %%
df = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\samples.csv", parse_dates=True, index_col=0)
df
# Out:
#              a   b      c   d
# 1950-01-01  36  27      0  67
# 1950-02-01  58  22      3  31
# 1950-03-01  61  17      5  67
# 1950-04-01  37  15      8  47
# 1950-05-01  66  13      8  62
# ...         ..  ..    ...  ..
# 1959-08-01  49  73   9338  58
# 1959-09-01  41  77   9502  38
# 1959-10-01  64  70   9667  42
# 1959-11-01  37  87   9833  62
# 1959-12-01  38  73  10000  50
#
# [120 rows x 4 columns]

# %% [markdown]
# # This is a stationary data as it has no trend or the mean and var of the data doesn't change with time

# %%
df['a'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # This is a non-stationary data as it has a particular trend or the mean and var of the data is changing with time

# %%
df['b'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # How to make data stationary
# ## Differening is done to make the data stationary

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
# 1st order differencing is sub the n-1 obs with n obs ie 
df['b'] - df['b'].shift(1)
# Out:
# 1950-01-01     NaN
# 1950-02-01    -5.0
# 1950-03-01    -5.0
# 1950-04-01    -2.0
# 1950-05-01    -2.0
#               ...
# 1959-08-01     3.0
# 1959-09-01     4.0
# 1959-10-01    -7.0
# 1959-11-01    17.0
# 1959-12-01   -14.0
# Name: b, Length: 120, dtype: float64

# %%
diff(df['b'], k_diff=1)
# Out:
# 1950-02-01    -5.0
# 1950-03-01    -5.0
# 1950-04-01    -2.0
# 1950-05-01    -2.0
# 1950-06-01     3.0
#               ...
# 1959-08-01     3.0
# 1959-09-01     4.0
# 1959-10-01    -7.0
# 1959-11-01    17.0
# 1959-12-01   -14.0
# Name: b, Length: 119, dtype: float64

# %% [markdown]
# # No trend and no seasonality

# %%
diff(df['b'], k_diff=1).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ACF and PACF

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.stattools import acovf, acf, pacf, pacf_yw, pacf_ols

# %%
# Non stationary data

# %%
dfs = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\airline_passengers.csv", parse_dates=['Month'], index_col=['Month'])

# %%
dfs
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
# Stationary data

# %%
dfns = pd.read_csv(r"E:\Course\Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\DailyTotalFemaleBirths.csv", parse_dates=['Date'], index_col=['Date'])

# %%
dfns
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
dfs.index.freq = 'MS'
dfns.index.freq = 'D'

# %%
acf(dfs['Thousands of Passengers'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:568: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(
# array([1.        , 0.94804734, 0.87557484, 0.80668116, 0.75262542,
#        0.71376997, 0.6817336 , 0.66290439, 0.65561048, 0.67094833,
#        0.70271992, 0.74324019, 0.76039504, 0.71266087, 0.64634228,
#        0.58592342, 0.53795519, 0.49974753, 0.46873401, 0.44987066,
#        0.4416288 , 0.45722376, 0.48248203, 0.51712699, 0.53218983,
#        0.49397569, 0.43772134, 0.3876029 , 0.34802503, 0.31498388,
#        0.28849682, 0.27080187, 0.26429011, 0.27679934, 0.2985215 ,
#        0.32558712, 0.3370236 , 0.30333486, 0.25397708, 0.21065534,
#        0.17217092])

# %% [markdown]
# # PACF with Yule_Walker Method

# %% [markdown]
# ## unbiased means the denominator will be n and biased me n-k where n is the no of obs and k is no of lag(s)

# %%
pacf_yw(dfs['Thousands of Passengers'], method='unbiased',nlags = 4 )
# Out:
# array([ 1.        ,  0.95467704, -0.26527732,  0.05546955,  0.10885622])

# %%
pacf_yw(dfs['Thousands of Passengers'], method='mle', nlags = 4) # maximum likelihood estimation
# Out:
# array([ 1.        ,  0.94804734, -0.22942187,  0.03814778,  0.09378544])

# %%
pacf_ols(dfs['Thousands of Passengers'], nlags = 4, unbiased = 'False')
# Out:
# array([ 1.        ,  0.9656378 , -0.33447646,  0.20611905,  0.14915107])

# %%
pacf_ols(dfs['Thousands of Passengers'], nlags = 4, unbiased = 'True')
# Out:
# array([ 1.        ,  0.9656378 , -0.33447646,  0.20611905,  0.14915107])

# %%
from pandas.plotting import lag_plot

# %% [markdown]
# # Showing high correlation between obs and lagged version of itself

# %%
lag_plot(dfs['Thousands of Passengers'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# # No autocorrelation

# %%
lag_plot(dfns['Births'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# # Blue shaded region is 95% cf
# # any data point lying in that region means highly likely to have high correalion

# %% [markdown]
# # No Stationary data as there significant strong correlation is noted from PACF and ACF

# %%
plot_acf(dfs['Thousands of Passengers'], lags = 40);

# %%
plot_pacf(dfs['Thousands of Passengers'], lags = 40);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# # Stationary data as no significant strong correlation is noted from PACF and ACF

# %%
plot_acf(dfns['Births'], lags = 40);

plot_pacf(dfns['Births'], lags = 40, title='Daily Female Birth PACF');
